# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
df0=pd.read_excel('/content/2010him (1).xlsx')
df1=pd.read_excel('/content/2011him.xlsx')
df2=pd.read_excel('/content/2012him (1).xlsx')
df3=pd.read_excel('/content/2013him.xlsx')
df4=pd.read_excel('/content/2014him.xlsx')
df5=pd.read_excel('/content/2015him.xlsx')
df6=pd.read_excel('/content/2016him.xlsx')
df7=pd.read_excel('/content/2017him.xlsx')
df8=pd.read_excel('/content/2018him.xlsx')
df9=pd.read_excel('/content/2019him.xlsx')

kufriSnow=pd.read_csv('/content/kufriSnowfall.csv')
kufriSnow.drop(columns=['Month'],inplace=True)
kufriWeather=pd.read_csv('/content/kufriWeatherToday.csv')
kufriWeather.drop(columns=['Month'],inplace=True)
rohtangTemp=pd.read_csv('/content/rohtangPassTemp.csv')
rohtangTemp.drop(columns=['Month'],inplace=True)
shimlaFootfall=pd.read_excel('/content/shimlaFootfall.xlsx')

shimlaTemperature=pd.read_csv('/content/shimlaTemperature.csv')
shimlaTemperature.drop(columns=['Month'],inplace=True)

# %%
kufriSnow.tail()
# Out:
#      kufri snowfall: (India)
# 115                        2
# 116                        5
# 117                       12
# 118                       33
# 119                       87

# %%
df2=pd.concat([df0,df1,df2,df3,df4,df5,df6,df7,df8,df9],axis=0)
df3=pd.concat([kufriSnow,kufriWeather,rohtangTemp,shimlaTemperature],axis=1)
df2= df2.reset_index(drop=True)
df2.head()
# Out:
#       1  shimla
# 0  Jan.  172312
# 1  Feb.  161860
# 2  Mar.  188961
# 3  Apr.  363600
# 4   May  369630

# %%
df3.shape
# Out:
# (120, 4)

# %%
df2=pd.concat([df2,df3],axis=1)

# %%
df2.tail(21)
# Out:
#         1  shimla  kufri snowfall: (India)  kufri weather today: (India)  \
# 99   Apr.  303675                        6                            17
# 100  May.  398789                       13                            22
# 101  June  403038                       10                            19
# 102  July  203486                        2                             8
# 103   Aug  243659                        2                             6
# 104  Sept  270853                        7                             6
# 105   Oct  195667                        8                            11
# 106   Nov  114514                       26                            20
# 107   Dec  178449                       61                            51
# 108  Jan.  251834                       51                            63
# 109  Feb.  204910                       19                            37
# 110  Mar.  248007                       10                            16
# ...

# %%
df2.head()
# Out:
#       1  shimla  kufri snowfall: (India)  kufri weather today: (India)  \
# 0  Jan.  172312                        0                             0
# 1  Feb.  161860                        0                            53
# 2  Mar.  188961                        0                             0
# 3  Apr.  363600                        0                             0
# 4   May  369630                        0                             0
#
#    rohtang pass temperature: (India)  shimla temperature: (India)
# 0                                  0                           21
# 1                                 24                            5
# 2                                  0                           12
# 3                                 53                           17
# 4                                 12                           23

# %%
df2.shape
# Out:
# (120, 6)

# %%
df3.tail()
# Out:
#      kufri snowfall: (India)  kufri weather today: (India)  \
# 115                        2                            11
# 116                        5                             7
# 117                       12                            10
# 118                       33                            31
# 119                       87                           100
#
#      rohtang pass temperature: (India)  shimla temperature: (India)
# 115                                 10                            9
# 116                                 15                           10
# 117                                 28                           12
# 118                                 30                           22
# 119                                 49                          100

# %%
start_date = pd.to_datetime('2010-01-01')

# Create a date-time range starting from the specified month, incrementing by one month
date_range = pd.date_range(start=start_date, periods=len(df2), freq='M')

# Set the date-time range as the index for the DataFrame
df2.index = date_range
df3.index= date_range
df2.head()
# Out:
#                1  shimla  kufri snowfall: (India)  \
# 2010-01-31  Jan.  172312                        0
# 2010-02-28  Feb.  161860                        0
# 2010-03-31  Mar.  188961                        0
# 2010-04-30  Apr.  363600                        0
# 2010-05-31   May  369630                        0
#
#             kufri weather today: (India)  rohtang pass temperature: (India)  \
# 2010-01-31                             0                                  0
# 2010-02-28                            53                                 24
# 2010-03-31                             0                                  0
# 2010-04-30                             0                                 53
# 2010-05-31                             0                                 12
#
#             shimla temperature: (India)
# 2010-01-31                           21
# 2010-02-28                            5
# 2010-03-31                           12
# 2010-04-30                           17
# ...

# %%
df2=df2.rename(columns={'shimla':'footfall'})
df2.head()
# Out:
#                1  footfall  kufri snowfall: (India)  \
# 2010-01-31  Jan.    172312                        0
# 2010-02-28  Feb.    161860                        0
# 2010-03-31  Mar.    188961                        0
# 2010-04-30  Apr.    363600                        0
# 2010-05-31   May    369630                        0
#
#             kufri weather today: (India)  rohtang pass temperature: (India)  \
# 2010-01-31                             0                                  0
# 2010-02-28                            53                                 24
# 2010-03-31                             0                                  0
# 2010-04-30                             0                                 53
# 2010-05-31                             0                                 12
#
#             shimla temperature: (India)
# 2010-01-31                           21
# 2010-02-28                            5
# 2010-03-31                           12
# ...

# %%
plt.plot(df2.index,df2['footfall'])
plt.show()

# %%
df2.keys()
# Out:
# Index([                                  1,
#                                 'footfall',
#                  'kufri snowfall: (India)',
#             'kufri weather today: (India)',
#        'rohtang pass temperature: (India)',
#              'shimla temperature: (India)'],
#       dtype='object')

# %%
df2.drop(columns=[1],inplace=True)
df2.head()
# Out:
#             footfall  kufri snowfall: (India)  kufri weather today: (India)  \
# 2010-01-31    172312                        0                             0
# 2010-02-28    161860                        0                            53
# 2010-03-31    188961                        0                             0
# 2010-04-30    363600                        0                             0
# 2010-05-31    369630                        0                             0
#
#             rohtang pass temperature: (India)  shimla temperature: (India)
# 2010-01-31                                  0                           21
# 2010-02-28                                 24                            5
# 2010-03-31                                  0                           12
# 2010-04-30                                 53                           17
# 2010-05-31                                 12                           23

# %%
### Testing For Stationarity

from statsmodels.tsa.stattools import adfuller

# %%
#test_result=adfuller(df2['footfall'])

def adfuller_test(sales):
    result=adfuller(sales)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adfuller_test(df2['footfall'])
# Out:
# ADF Test Statistic : -2.335827610298617
# p-value : 0.16067301420196645
# #Lags Used : 12
# Number of Observations Used : 107
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
for column_name in df2.keys():
  print('column: ',df2[column_name])
  print(adfuller_test(df2[column_name]))
  print('--------------------------------')
# Out:
# column:  2010-01-31    172312
# 2010-02-28    161860
# 2010-03-31    188961
# 2010-04-30    363600
# 2010-05-31    369630
#                ...
# 2019-08-31    253127
# 2019-09-30    285213
# 2019-10-31    213314
# 2019-11-30    133885
# 2019-12-31    198985
# Freq: M, Name: footfall, Length: 120, dtype: int64
# ADF Test Statistic : -2.335827610298617
# p-value : 0.16067301420196645
# #Lags Used : 12
# Number of Observations Used : 107
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary
# None
# --------------------------------
# column:  2010-01-31     0
# 2010-02-28     0
# 2010-03-31     0
# 2010-04-30     0
# 2010-05-31     0
#               ..
# 2019-08-31     2
# 2019-09-30     5
# 2019-10-31    12
# 2019-11-30    33
# 2019-12-31    87
# Freq: M, Name: kufri snowfall: (India), Length: 120, dtype: int64
# ADF Test Statistic : -0.971711429106692
# p-value : 0.7634415981972116
# #Lags Used : 12
# Number of Observations Used : 107
# ...

# %% [markdown]
# **The data is non stationary, we have to make it stationary**

# %%
  df2['footfall'].plot()
# Out:
# <Axes: >

# %%
df2['kufri snowfall: (India)'].plot()
# Out:
# <Axes: >

# %%
df2['kufri weather today: (India)'].plot()
# Out:
# <Axes: >

# %%
df2['rohtang pass temperature: (India)'].plot()
# Out:
# <Axes: >

# %%
df2['shimla temperature: (India)'].plot()
# Out:
# <Axes: >

# %%
#differencing

df2['footfallDifference']=df2['footfall']-df2['footfall'].shift(6)

# %%
df2['kufriSnowDifference']=df2['kufri snowfall: (India)']-df2['kufri snowfall: (India)'].shift(6)

# %%
adfuller_test(df2['kufriSnowDifference'].dropna())
# Out:
# ADF Test Statistic : -7.301569268903593
# p-value : 1.3343993038180962e-10
# #Lags Used : 6
# Number of Observations Used : 107
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %%
df2['kufriWeatherDifference']=df2['kufri weather today: (India)']-df2['kufri weather today: (India)'].shift(6)
adfuller_test(df2['kufriWeatherDifference'].dropna())
# Out:
# ADF Test Statistic : -15.35413750746472
# p-value : 3.6861784849279407e-28
# #Lags Used : 5
# Number of Observations Used : 108
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %%
df2['rohtangTempDifference']=df2['rohtang pass temperature: (India)']-df2['rohtang pass temperature: (India)'].shift(12)
adfuller_test(df2['rohtangTempDifference'].dropna())
# Out:
# ADF Test Statistic : -4.114759425826443
# p-value : 0.0009155256990075243
# #Lags Used : 11
# Number of Observations Used : 96
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %%
df2['shimlaTempDifference']=df2['shimla temperature: (India)']-df2['shimla temperature: (India)'].shift(6)
adfuller_test(df2['shimlaTempDifference'].dropna())
# Out:
# ADF Test Statistic : -17.640700607869622
# p-value : 3.7601324789368175e-30
# #Lags Used : 5
# Number of Observations Used : 108
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %%
data=df2.to_excel('shimlaTrainingData.xlsx',index=True)

# %%
df2.head()
# Out:
#             footfall  kufri snowfall: (India)  kufri weather today: (India)  \
# 2010-01-31    172312                        0                             0
# 2010-02-28    161860                        0                            53
# 2010-03-31    188961                        0                             0
# 2010-04-30    363600                        0                             0
# 2010-05-31    369630                        0                             0
#
#             rohtang pass temperature: (India)  shimla temperature: (India)  \
# 2010-01-31                                  0                           21
# 2010-02-28                                 24                            5
# 2010-03-31                                  0                           12
# 2010-04-30                                 53                           17
# 2010-05-31                                 12                           23
#
# ...

# %%
adfuller_test(df2['footfallDifference'].dropna())
# Out:
# ADF Test Statistic : -7.636181456035562
# p-value : 1.9496964904823335e-11
# #Lags Used : 6
# Number of Observations Used : 107
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %% [markdown]
# **we try to make the p value zero**

# %%
df2['footfallDifference'].plot()

plt.legend()

# %% [markdown]
# **Auto correlation part, to know how the lagging part is correlated with the present part**

# %%
df2.isnull().sum()
# Out:
# footfall                              0
# kufri snowfall: (India)               0
# kufri weather today: (India)          0
# rohtang pass temperature: (India)     0
# shimla temperature: (India)           0
# footfallDifference                    6
# kufriSnowDifference                   6
# kufriWeatherDifference                6
# rohtangTempDifference                12
# shimlaTempDifference                  6
# dtype: int64

# %% [markdown]
# #Finding The AutoCorrelations between the lagged part and present part w.r.t lag

# %%
import statsmodels.api as sm

sm.graphics.tsa.plot_acf(df2['footfallDifference'].iloc[7:], lags=30)  # Adjust 'lags' as needed
plt.title('Autocorrelation Plot')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')

sm.graphics.tsa.plot_pacf(df2['footfallDifference'].iloc[7:],lags=30)
plt.title('partial-Autocorrelation Plot')
plt.xlabel('Lag')b
plt.ylabel('Autocorrelation')
plt.show()

# %% [markdown]
# **from the ACF plot we obtain the q value as 24,  and p value from the PACF plot, as 12**

# %%
from statsmodels.tsa.arima_model import ARIMA
model=sm.tsa.ARIMA(df2['footfall'],order=(12,1,24))

model_fit=model.fit()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
sm.graphics.tsa.plot_acf(df2['kufriSnowDifference'].iloc[7:], lags=50)  # Adjust 'lags' as needed
plt.title('Autocorrelation Plot')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')

sm.graphics.tsa.plot_pacf(df2['kufriSnowDifference'].iloc[7:],lags=50)
plt.title('partial-Autocorrelation Plot')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.show()

# %% [markdown]
# p=19, q=24

# %%
import statsmodels.api as sm
model_kufriSnow=sm.tsa.ARIMA(df2['kufri snowfall: (India)'],order=(19,1,24))

model_kufriSnow_fit=model_kufriSnow.fit()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
sm.graphics.tsa.plot_acf(df2['kufriWeatherDifference'].iloc[7:], lags=50)  # Adjust 'lags' as needed
plt.title('Autocorrelation Plot')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')

sm.graphics.tsa.plot_pacf(df2['kufriWeatherDifference'].iloc[7:],lags=50)
plt.title('partial-Autocorrelation Plot')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.show()

# %% [markdown]
# q=18,p=6

# %%
model_kufriWeather=sm.tsa.ARIMA(df2['kufri weather today: (India)'],order=(6,1,18))
model_kufriWeather_fit=model_kufriWeather.fit()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
sm.graphics.tsa.plot_acf(df2['rohtangTempDifference'].iloc[13:], lags=50)  # Adjust 'lags' as needed
plt.title('Autocorrelation Plot')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')

sm.graphics.tsa.plot_pacf(df2['rohtangTempDifference'].iloc[13:],lags=50)
plt.title('partial-Autocorrelation Plot')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.show()

# %% [markdown]
# p=18,q=12

# %%
model_rohtangTemp=sm.tsa.ARIMA(df2['rohtang pass temperature: (India)'],order=(18,1,12))
model_rohtangTemp_fit=model_rohtangTemp.fit()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
sm.graphics.tsa.plot_acf(df2['shimlaTempDifference'].iloc[7:], lags=50)  # Adjust 'lags' as needed
plt.title('Autocorrelation Plot')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')

sm.graphics.tsa.plot_pacf(df2['shimlaTempDifference'].iloc[7:],lags=50)
plt.title('partial-Autocorrelation Plot')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.show()

# %% [markdown]
# p=6,q=24

# %%
model_shimlaTemp=sm.tsa.ARIMA(df2['shimla temperature: (India)'],order=(6,1,24))
model_shimlaTemp_fit=model_shimlaTemp.fit()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# **prediction over testing data for footfall, from index=102 to 119**

# %%
df_predict=pd.DataFrame()
df_predict['forecast']=model_fit.predict(start=102,end=len(df2)-1,dynamic=True)
df_predict['forecast'].plot(figsize=(8,5)) #d=1
df2['footfall'].plot(figsize=(8,5))
# Out:
# <Axes: >

# %% [markdown]
# footfall prediction, directly. The forecast starts to predict just after the fit data

# %%
forecast = model_fit.forecast(steps=100)
'''
forecasted = pd.DataFrame(forecast)
forecasted.columns=['forecasted_footfall']
forecasted['forecasted_footfall']=forecasted['forecasted_footfall'].astype(int)
'''
# Out:
# "\nforecasted = pd.DataFrame(forecast)\nforecasted.columns=['forecasted_footfall']\nforecasted['forecasted_footfall']=forecasted['forecasted_footfall'].astype(int)\n"

# %%
forecast
# Out:
# 2020-01-31    274016.134394
# 2020-02-29    238907.616493
# 2020-03-31    250209.289314
# 2020-04-30    292501.542605
# 2020-05-31    440836.253538
#                   ...
# 2027-12-31    257635.926897
# 2028-01-31    258189.219720
# 2028-02-29    236662.936375
# 2028-03-31    219544.480117
# 2028-04-30    218692.246277
# Freq: M, Name: predicted_mean, Length: 100, dtype: float64

# %%
forecast.plot()
# Out:
# <Axes: >

# %%
df_new=pd.concat([df2['footfall'],forecast])
df_new.plot()
forecast.plot() #d=1
# Out:
# <Axes: >

# %%
df_predict['kufri snowfall: (India)']=model_kufriSnow_fit.predict(start=102,end=len(df2)-1,dynamic=True)
df_predict['kufri snowfall: (India)'].plot(figsize=(8,5)) #d=1
df2['kufri snowfall: (India)'].plot(figsize=(8,5))
# Out:
# <Axes: >

# %%
df_predict['kufri weather today: (India)']=model_kufriWeather_fit.predict(start=102,end=len(df2)-1,dynamic=True)
df_predict['kufri weather today: (India)'].plot(figsize=(8,5)) #d=1
df2['kufri weather today: (India)'].plot(figsize=(8,5))
# Out:
# <Axes: >

# %%
df_predict['rohtang pass temperature: (India)']=model_rohtangTemp_fit.predict(start=102,end=len(df2)-1,dynamic=True)
df_predict['rohtang pass temperature: (India)'].plot(figsize=(8,5)) #d=1
df2['rohtang pass temperature: (India)'].plot(figsize=(8,5))
# Out:
# <Axes: >

# %%
df_predict['shimla temperature: (India)']=model_shimlaTemp_fit.predict(start=102,end=len(df2)-1,dynamic=True)
df_predict['shimla temperature: (India)'].plot(figsize=(8,5)) #d=1
df2['shimla temperature: (India)'].plot(figsize=(8,5))
# Out:
# <Axes: >

# %% [markdown]
# forecasted dataframe

# %%
df_predict.head()
# Out:
#                  forecast  kufri snowfall: (India)  \
# 2018-07-31  248322.488639                -2.581158
# 2018-08-31  271274.592186                 3.487895
# 2018-09-30  292995.174045                10.484719
# 2018-10-31  202767.273400                 9.121359
# 2018-11-30  130853.195615                33.207663
#
#             kufri weather today: (India)  rohtang pass temperature: (India)  \
# 2018-07-31                     11.212095                          30.203075
# 2018-08-31                      2.589721                          11.405243
# 2018-09-30                      3.430694                          22.364830
# 2018-10-31                      6.317712                          22.144262
# 2018-11-30                     29.680822                          41.132872
#
#             shimla temperature: (India)
# 2018-07-31                    22.467866
# 2018-08-31                    18.978605
# 2018-09-30                    12.963372
# ...

# %% [markdown]
# **error due to pure arima**

# %%
df2
# Out:
#             footfall  kufri snowfall: (India)  kufri weather today: (India)  \
# 2010-01-31    172312                        0                             0
# 2010-02-28    161860                        0                            53
# 2010-03-31    188961                        0                             0
# 2010-04-30    363600                        0                             0
# 2010-05-31    369630                        0                             0
# ...              ...                      ...                           ...
# 2019-08-31    253127                        2                            11
# 2019-09-30    285213                        5                             7
# 2019-10-31    213314                       12                            10
# 2019-11-30    133885                       33                            31
# 2019-12-31    198985                       87                           100
#
# ...

# %%
print(df_predict.shape)
# Out:
# (18, 5)

# %% [markdown]
# **kinda training error, the very last part**

# %%
from sklearn.metrics import mean_squared_error
column=df2.columns
column=column[1:5]
for i in column:

  print('rmse: ',np.sqrt(mean_squared_error(df2[i][len(df2)-18:],df_predict[i])))
# Out:
# rmse:  6.66318539375145
# rmse:  16.454030270647213
# rmse:  7.552684782042089
# rmse:  13.393384263097873

# %%
foreCast=pd.DataFrame()
foreCast['shimlaTemp']= model_shimlaTemp_fit.forecast(steps=100)
foreCast['rohtangTemp']=model_rohtangTemp_fit.forecast(steps=100)
foreCast['kufriWeather']=model_kufriWeather_fit.forecast(steps=100)
foreCast['kufriSnow']=model_kufriSnow_fit.forecast(steps=100)
foreCast['footfall']=forecast

# %%
foreCast.head()
# Out:
#             shimlaTemp  rohtangTemp  kufriWeather  kufriSnow       footfall
# 2020-01-31   47.839768    42.031823     71.398074  56.414832  274016.134394
# 2020-02-29   36.106766    19.221585     38.457365  21.492697  238907.616493
# 2020-03-31   27.218331    24.308672     23.469271  18.242539  250209.289314
# 2020-04-30   17.753753    27.176626      0.180148  12.798089  292501.542605
# 2020-05-31   29.719250    68.493090     23.160676  17.277927  440836.253538

# %% [markdown]
# #Now a supervised ml model is needed to know the weights of each feature----

# %%
import xgboost as xgb
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
xData=df2[['kufri snowfall: (India)', 'kufri weather today: (India)',
       'rohtang pass temperature: (India)', 'shimla temperature: (India)']]
yData=df2['footfall']

# %% [markdown]
# **fit only a part of the data, train size=100**

# %%
modelXGB= XGBRegressor()
modelXGB.fit(xData[:100], yData[:100])
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
x_cast=pd.DataFrame()
x_cast=foreCast[['kufriSnow', 'kufriWeather','rohtangTemp',	'shimlaTemp']]
x_cast=x_cast.rename(columns={'shimlaTemp':'shimla temperature: (India)','rohtangTemp':'rohtang pass temperature: (India)','kufriWeather':'kufri weather today: (India)','kufriSnow':'kufri snowfall: (India)'})
x_cast.head()
# Out:
#             kufri snowfall: (India)  kufri weather today: (India)  \
# 2020-01-31                56.414832                     71.398074
# 2020-02-29                21.492697                     38.457365
# 2020-03-31                18.242539                     23.469271
# 2020-04-30                12.798089                      0.180148
# 2020-05-31                17.277927                     23.160676
#
#             rohtang pass temperature: (India)  shimla temperature: (India)
# 2020-01-31                          42.031823                    47.839768
# 2020-02-29                          19.221585                    36.106766
# 2020-03-31                          24.308672                    27.218331
# 2020-04-30                          27.176626                    17.753753
# 2020-05-31                          68.493090                    29.719250

# %%
x_cast.shape
# Out:
# (100, 4)

# %%
x_cast.head(10)
# Out:
#             kufri snowfall: (India)  kufri weather today: (India)  \
# 2020-01-31                56.414832                     71.398074
# 2020-02-29                21.492697                     38.457365
# 2020-03-31                18.242539                     23.469271
# 2020-04-30                12.798089                      0.180148
# 2020-05-31                17.277927                     23.160676
# 2020-06-30                14.534896                     26.046594
# 2020-07-31                 8.733764                     16.662292
# 2020-08-31                14.742276                     17.407438
# 2020-09-30                21.611115                     11.869338
# 2020-10-31                20.318590                      9.370242
#
#             rohtang pass temperature: (India)  shimla temperature: (India)
# 2020-01-31                          42.031823                    47.839768
# 2020-02-29                          19.221585                    36.106766
# ...

# %% [markdown]
# #Errors------------

# %%
#over the training data
yTrain_pred=modelXGB.predict(xData[:100])
rmse_train=np.sqrt(mean_squared_error(yData[:100],yTrain_pred))
y_true_range = yData.max() - yData.min()
nrmse_train = rmse_train / y_true_range
print('training rmse: ',rmse_train)
print('training nrmse: ',nrmse_train)

yTest_pred=modelXGB.predict(xData[100:])
rmse_test=np.sqrt(mean_squared_error(yData[100:],yTest_pred))

nrmse_test = rmse_test / y_true_range
print('testing rmse: ',rmse_test)
print('testing nrmse: ',nrmse_test)
# Out:
# training rmse:  4430.334481319969
# training nrmse:  0.011405042762643631
# testing rmse:  82897.05636564002
# testing nrmse:  0.21340250419776863

# %%
predictionXGB=modelXGB.predict(x_cast)
print(type(predictionXGB))
predict= pd.DataFrame({'predictedFootfall': predictionXGB})
predict.reset_index()

start_date = pd.to_datetime('2020-01-31')

# Create a date-time range starting from the specified month, incrementing by one month
date_range = pd.date_range(start=start_date, periods=len(predict), freq='M')

# Set the date-time range as the index for the DataFrame
predict.index = date_range
'''
plt.plot(predictionXGB)
plt.ylabel('prediction')

plt.plot(df2['footfall'][124:len(df2)].to_numpy())
plt.ylabel('actual')
plt.legend(['predict','actual'])
plt.show()
'''
predict.plot()
df2['footfall'].plot()
# Out:
# <class 'numpy.ndarray'>
# <Axes: >

# %% [markdown]
# **This is forecasted using the google search index data**

# %%
forecast.head()
# Out:
# 2020-01-31    274016.134394
# 2020-02-29    238907.616493
# 2020-03-31    250209.289314
# 2020-04-30    292501.542605
# 2020-05-31    440836.253538
# Freq: M, Name: predicted_mean, dtype: float64

# %% [markdown]
# ##forecasting only using government tourist footfall data

# %%
df_new.plot()
forecast.plot() #d=1
# Out:
# <Axes: >

# %%
directModel=sm.tsa.ARIMA(df2['footfall'][:100],order=(12,1,24))
directModel_fit=directModel.fit()

directPredict=pd.DataFrame(columns=['footfall'])
directPredict['footfall']=directModel_fit.predict(start=100,end=len(df2)-1,dynamic=True)
rmseD=np.sqrt(mean_squared_error(df2['footfall'][100:],directPredict['footfall']))
print('testing rmse:',rmseD)
y_range=yData.max()-yData.min()
print('testing nrmse: ',rmseD/y_range)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# testing rmse: 104489.72976711742
# testing nrmse:  0.26898868274523474
